# %%
x = 56e6#float
y = 67E6#float
z = -89.9e89#float only

print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
#complex
x = 8+9j
y = 7j
z = -4j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
# Mod Operator
a= 2
b=5
print(a/b)
# Out:
# 0.4

# %%
#convert string to integer
num_int = 123
num_str = "456"

print(type(num_int))
print(type(num_str))

b = num_int+num_str
print(b)
# Out:
# <class 'int'>
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-446853722.py in <cell line: 0>()
#       6 print(type(num_str))
#       7
# ----> 8 b = num_int+num_str
#       9 print(b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#explicit type conversion
num_int = 123
num_str = "456"

print(type(num_int))
print(type(num_str))

num_str = int(num_str)
print(type(num_str))

num_sum = num_int + num_str

print("Sum of num_int and num_str:",num_sum)
print(type(num_sum))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>
# Sum of num_int and num_str: 579
# <class 'int'>

# %%
(2.564, 2)
# Out:
# (2.564, 2)

# %%
ord('d')
# Out:
# 100

# %%
chr(67)
# Out:
# 'C'

# %%
#Find the given number is perfect or not:
x = int(input())
z = 0
for i in range(1,x):
 if (x%i==0):
  z = z+i
if z==x:
   print('given no. is perfect')
else:
    print('given no. is not perfect')
# Out:
# 6
# given no. is perfect
