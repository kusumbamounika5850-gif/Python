# %%
# question

a = 356

b = a % 10
c = a // 10
d = c % 10
e = c // 10


f = str(b) + str(d) + str(e)

print(int(f))
# Out:
# 653

# %%
'ka'+'mp'
# Out:
# 'kamp'

# %%
'10' + '20'
# Out:
# '1020'

# %%
10 + 20
# Out:
# 30

# %%
a = 10
b = 20

b,a = a,b

print(a)
print(b)
# Out:
# 20
# 10

# %%
a = 10
b = 20

t = a

a = b


b = t

print(a)
print(b)
# Out:
# 20
# 10

# %%
a = 100
b = 200

print(f"Before a value : {a} and b value : {b}")
a = a + b
b = a - b
a = a - b

print(a)
print(b)
print(f"After a value : {a} and b value : {b}")
# Out:
# Before a value : 100 and b value : 200
# 200
# 100
# After a value : 200 and b value : 100
