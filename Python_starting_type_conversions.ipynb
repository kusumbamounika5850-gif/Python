# %% [markdown]
# #Data types of python
#
# *3 Data types\*
#
# *  integer:-example of integer values 1, 2, 3, etc
# *  float:-example of decimal values 56.55 etc
# *   string:- anything right from in between of codes ''.
# * variables :- variable is ntg but storing the value of in temporary memory
# ex: a=12.
# * print():print is ntg but print the a value of variable .
# * = equal symbol is a Operator it is used to right side value will reaching the left side content.
# *address: id is ntg but find the variable value in the memory of the location.
# ex: Print( id() ).

# %%
a = 12 #save in the memory
b=30 #save in the memory
c=25 #save in the memory
a #calling from memory
# Out:
# 12

# %%
print(b)
# Out:
# 30

# %%
a + 20
# Out:
# 32

# %%
print(id(a))
# Out:
# 11654728

# %%
f = 24.67 #save in the meomory
k = 0.56 #save in the meomory
print(f)
print(id(f)) #calling from memory
# Out:
# 24.67
# 138077803269648

# %%
f
# Out:
# 24.67

# %%
print(a)
# Out:
# 12

# %% [markdown]
# ##'Rules to create the variables'
#
#
# Rule no:1 -> Varibales should not start with a Number if you want to start please use underscore_
#
# Rule no:2 -> Varibale should be either single character or single word multiple charaters with space multiple words with space is not allowed if you want please use underscore
#
# Rule no:3 -> Python Varibales are case sensitive (capital means capital small means small )
#
# Rule no:4 -> Dont use below Punctuations as varibale -> !"#$%&'()*+,-./:;<=>?@[\]^_{|}~`

# %%
# underscore_

_234 = 24.5
print(_234)
# Out:
# 24.5

# %% [markdown]
# ```
# Step 2: Variable should not either single character or single word (or) multiple characters  with space or multiple words with space if you want to use plz maintain underscore_
# ```

# %%
# under score with sinle word

_kusumba  = 345
print(_kusumba)
# Out:
# 345

# %%
# under score with multiple words

kusumba_mounika = 12345
print(kusumba_mounika)
# Out:
# 12345

# %%
#under score with multiple characters

_2abc_ab345 = 78654
print(_2abc_ab345)
# Out:
# 78654

# %% [markdown]
# Step 3: Python variables are case sensitive capital means capital, small means small.

# %%
# capital means capital

HYDERABAD = 56786
CITY = 'hyderabad'
COLONY = 'PRAGATHINAGAR'
print(HYDERABAD)
print(CITY)
print(COLONY)
# Out:
# 56786
# hyderabad
# PRAGATHINAGAR

# %% [markdown]
# Step 4: Do'nt use below punctuations !@%#$&&*^$%#$%&

# %%
_@234 = 87643

print(_234)
# Out:
#   File "/tmp/ipython-input-594615795.py", line 1
#     _@234 = 87643
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# #
#
# ```
# #Type conversions
# ```
#
# ```
# .type conversions nothing but data type conversions
# ```
#
#
# ```
# .6 possibilities is there (one data type convert to another data type)
# ```
#
# ```
# int  ----->float and int------>str
# float------>int and float----->str
# str-------->float and str------->int
# ```

# %%
# int------->float

a =234 #saving the memory
b =34.57 #saving the memory
c = 789 # saving the memory

print(b) #calling the memory
print(type(b))
print(c)
# Out:
# 34.57
# <class 'float'>
# 789

# %%
# int --------> str

Course = 'Data science'
time = '1.6hours'
Duration = '6 months'

print(Course) # calling the memory
print(type(Duration))
# Out:
# Data science
# <class 'str'>

# %%
# int ------>float

a = 234 # save  the memory
print(a) # calling the memory
print(type(a)) # calling and checking the data

b = float(a) # actual conversions happends here
print(b) # calling from meomory
print(type(b)) # calling and checking the data type
# Out:
# 234
# <class 'int'>
# 234.0
# <class 'float'>

# %%
# int ------>str

a = 234 # save  the memory
print(a) # calling the memory
print(type(a)) # calling and checking the data

b = str(a) # actual conversions happends here
print(b) # calling from meomory
print(type(b)) # calling and checking the data type
# Out:
# 234
# <class 'int'>
# 234
# <class 'str'>

# %%
# float------>int

a = 25.898 # save  the memory
print(a) # calling the memory
print(type(a)) # calling and checking the data

b = int(a) # actual conversions happends here
print(b) # calling from meomory
print(type(b)) # calling and checking the data type
# Out:
# 25.898
# <class 'float'>
# 25
# <class 'int'>

# %%
# float------>str

a = 25.898 # save  the memory
print(a) # calling from memory
print(type(a)) # calling and checking the data

b = str(a) # actual conversions happends here
print(b) # calling from meomory
print(type(b)) # calling and checking the data type
# Out:
# 25.898
# <class 'float'>
# 25.898
# <class 'str'>

# %%
# str------>int

a = '25898' # save  the memory
print(a) # calling from memory
print(type(a)) # calling and checking the data

b = int(a) # actual conversions happends here
print(b) # calling from meomory
print(type(b)) # calling and checking the data type
# Out:
# 25898
# <class 'str'>
# 25898
# <class 'int'>

# %%
# str------>float

a = '25898' # save  the memory
print(a) # calling from memory
print(type(a)) # calling and checking the data

b = float(a) # actual conversions happends here
print(b) # calling from meomory
print(type(b)) # calling and checking the data type
# Out:
# 25898
# <class 'str'>
# 25898.0
# <class 'float'>

# %% [markdown]
# #Print Conditions
#
#
#
# ```
# .to create the relation between str and float & str and int > inside the print condition
# ```
# 4' different ways we have to use print conditions

# %% [markdown]
# Step 1 : using with comma (,) will give us one tab spce
# -> only 10% of developers will use

# %%
# using with comma (,)

f = 28
print('my name is mouni my age is',28)
# Out:
# my name is mouni my age is 28

# %%
course = 'data science'
time = 6
duration = 1.30

print('i am learning',course,'study in VT for',time,'months with',duration,'hours daily')
# Out:
# i am learning data science study in VT for 6 months with 1.3 hours daily

# %% [markdown]
# . using with + not give us tab space it's only create relation with str only

# %%
#using with +

course = 'data science'
time = 6
duration = 1.30

print('i am learning '+str(course)+' study in VT for ' +str(time)+' months with ' +str(duration)+ 'hours daily')
# Out:
# i am learning data science study in VT for 6 months with 1.3hours daily

# %%
f = 28
print('my name is mouni my age is ' +str(f))
# Out:
# my name is mouni my age is 28

# %% [markdown]
# .Using with identifiers %d----> int,
# %f------> float, and %s--------> str

# %%
# using with %d

f = 28
print('my name is mouni my age is %d'%(f))
# Out:
# my name is mouni my age is 28

# %%
#using with %f

course = 'data science'
time = 6
duration = 1.30

print('i am learning %s study in VT for %d months with %f hours daily' %(course,time,duration))
# Out:
# i am learning data science study in VT for 6 months with 1.300000 hours daily

# %% [markdown]
# .Using with f and {}
# ** Real time 100% using this condition**

# %%
# using with f and {}


course = 'data science'
time = 6
duration = 1.30

print(f'I am learning {course} in VT for {time} months {duration} hours duration daily')
# Out:
# I am learning data science in VT for 6 months 1.3 hours duration daily

# %%
course = 'data science'
time = 6
duration = 1.30

print(f' i am learning {course} in VT for {time}  months {duration} hours daily')
# Out:
#  i am learning data science in VT for 6  months 1.3 hours daily

# %% [markdown]
# .Convert int,float & complex

# %%
x = 5    # int
y = 7.8  # float
z = 6j   # complex

# convert int float

x = float(x) # save in the memory
print(x)

#convert float to int
y = int(y)
print(y)

#convert complex to float
z = str(z)
print(z)

print(type(x)) #calling from memory and checking data
print(type(y))
print(type(z))
# Out:
# 5.0
# 7
# 6j
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
#explicit type conversion
# convert str to int
num_int = 123
num_str = "456"

print(num_int)
print(num_str)

num_str = int(num_int) # actual happends here
num_sum = num_int + num_str # we are adding sum

print(type(num_str))
print(type(num_int))
# Out:
# 123
# 456
# <class 'int'>
# <class 'int'>

# %%
x = 54e5
y = 21E5



print(type(x))
print(type(y))
# Out:
# <class 'float'>
# <class 'float'>

# %% [markdown]
# #Operators
#
# # +,-,*,/,//,%,>,<,>=,<=,!=,=,==,and,or,pow,**
#
# * Arithmatic Operators
#
# *Assignment operators
#
# *Comparison operators
#
# *Logical operators
#
# *Identity Operators
#
# *membership operators
#
# *Bitwise operators

# %%
#using + operator
3748957 + 749879
# Out:
# 4498836

# %%
#using - operator

20 - 10
# Out:
# 10

# %%
#using / division operator

40/6
# Out:
# 6.666666666666667

# %%
#using // floor division

567//5 # expect before the dot numbers only
# Out:
# 113

# %%
#using % modulus

456%8 #expect reminder value only
# Out:
# 0

# %%
#using * Multiplication


456 * 678
# Out:
# 309168

# %%
#using ** Exponentiation (power)


46 ** 6 #power
# Out:
# 9474296896

# %%
#using **

x = 40
y = 3

x  ** y
# Out:
# 64000

# %%
# using = operator


x = 10
y = 15

x = y

# %%
# using == operator

x = 20
y = 30

x == y
# Out:
# False

# %%
#using += operator

x = 30
x += 35
print(x)
# Out:
# 65

# %%
# using != operator

x = 26
y = 80

print(x != y)
# Out:
# True

# %%
# using >= operator

x = 26
y = 80

print(x <= y)
# Out:
# True

# %%
# using or operator

x = 20
y = 30

a = 10
b = 20

print(x>=y or a<=b)
# Out:
# True

# %%
# using and operator

x = 27
y = 30

a = 4
b = 6

print(x!=y and a==b)
# Out:
# False

# %%
#using = assign

x = 5

print( x + 3)
# Out:
# 8

# %%
#using the swap the values

x = 400
y = 300
x, y = y, x
print(f' x : {x} , y : {y}')
# Out:
#  x : 300 , y : 400

# %%
# using the &=  operator

x = 12
y = 10

print(x & y)
# Out:
# 8

# %%
2**0
# Out:
# 1

# %%
345**0
# Out:
# 1

# %%
10 > 5 < 2
# Out:
# False

# %%
3 * "Hello"
# Out:
# 'HelloHelloHello'

# %%
-5 // 2
# Out:
# -3

# %%
-7 // 2
# Out:
# -4

# %%
8 % 3 + 2 ** 2 * (2 + 2)
# Out:
# 18

# %%
(3 + 2) * 4 / 2 ** 2
# Out:
# 5.0

# %%
x = 5
y = x * 2 if x < 10 else x / 2
print(y)
# Out:
# 10

# %%
x = 5
y = x if x < 10 else x / 2
print(y)
# Out:
# 5

# %%
x = 5
y = x if x != 5 else x + 2
print(y)
# Out:
# 7

# %% [markdown]
# #Functions
# functions = functions means which is used to execute a given task or designed task
# *Built_in_functions = functions means which is used to execute a given task or designed task developed by python community
#
# *Library = it is like a box where we have built_in_functions
#             # ex: math library(box) -> only math built_in_functions are available
#             # ex: sklearn library (box) -> only machine learning built in functions are available

# %%
import math #opening the box

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
len(dir(math))
# Out:
# 66

# %%
 math.factorial(6)
# Out:
# 720

# %%
math.factorial(9)
# Out:
# 362880

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.degrees(2.5)
# Out:
# 143.2394487827058

# %%
# using swap values

a = 30
b = 20

a,b = b,a

print(f' a_value : {a} ,  b : {b}')
# Out:
#  a_value : 20 ,  b : 30

# %%
# using swap values

x = 40
y = 30

x = x + y #70
y = x - y # 40
x = x - y # 30
print(x)
print(y)
# Out:
# 30
# 40

# %%
# using swap values * // operators

a = 20
b = 10

a = a*b # 200
b = a//b #
a = a//b

print(a)
print(b)
# Out:
# 10
# 20

# %%
a = 458
b = a%10 # 8
c = a//10 #45
d = c%10 # 5
e = c//10 # 4

f = str(b)+ str(d) + str(e)
print(f)
type(f)
# Out:
# 854
# str

# %%
a = 854

print(type(a))
# Out:
# <class 'int'>

# %%
a = 567

b = a%10 #7
c = a//10 #56
d = c%10 # 6
e = c//10
f = (str(b)+str(d)+str(e))



k = int(f)

print(type(k))
# Out:
# <class 'int'>

# %%
a = 30
b = 10

a = a+b #30
b = a-b
a = a-b

print(a)
print(b)
# Out:
# 10
# 30

# %%
#Assignment
a = 20
b = 10

print(f'sum of two no.s : {a+b}')
print(f'difference of two no.s : {a-b}')
print(f'product of two no.s : {a*b}')
# Out:
# sum of two no.s : 30
# difference of two no.s : 10
# product of two no.s : 200

# %%
a = 2
b = 5

print(a+b)
print(a-b)
print(a*b)
# Out:
# 7
# -3
# 10

# %%
a = 21
if a % 2 == 0:
  print(a, 'is even')
else:
  print(a, 'is odd')
# Out:
# 21 is odd

# %%
# user input

a =int(input())

if a % 2 == 0:

  print(a, 'is even')

else:
  print(a, ' is odd')
# Out:
# 26
# 26 is even

# %%
a = int(input())

b = a**2
c = a**3

print(f'square of no:{b}')
print (f'cube of no: {c}')
# Out:
# 36
# square of no:1296
# cube of no: 46656

# %%
a = int(input())
b = int(input())

if a == b:
  print( 'number is equal to')

else:
  print('number is not equal to')

if a>b:

 print('a is greater than b')

else:

  print('b is greater than a')
# Out:
# 2
# 3
# number is not equal to
# b is greater than a

# %%
a = int(input())
b = int(input())
if (a==b):
  print('They are equal')
else:
  if( a>b ):
    print(f'{a} is greater')
  else:
    print(f'{b} is greater')
# Out:
# 10
# 10
# They are equal

# %%
k = str(input())

print('a' in k)
# Out:
# venu
# False

# %%
a = int(input())

if (a%3==0 and a%5==0):

 print(f'given {a} is divisible')
else:
  print(f'given{a} is not divisible')
# Out:
# 20
# given 20 is divisible

# %%
a = int(input())

if(a>=10 and a<=50):

 print('the no.s lies between')

else:
  print('the no.s not')
# Out:
# 55
# the no.s not

# %%
#program to check if a number is positive, negative, or zero using

a = int(input())


if (a > 0):

 print('the no. is positive ')

elif (a < 0):

  print('the no. is negative')
# Out:
# 0

# %%
#Input a number and check if it is a multiple of either 4 or 6

x = int(input())

if (x%4==0 and x%6==0):

 print(f'the given no. is divisible {x}')

else:
  print(f'the given no. is not divisible {x}')
# Out:
# 24
# the given no. is divisible 24

# %%
#True if it is between 100 and 200 (exclusive)
#False otherwise


a = int(input())

if (a>100 and a<200):

 print('the given no. is lies between 100 and 200 ')

else :

 print('the given no. is not between 100 and 200 ')
# Out:
# 130
# the given no. is lies between 100 and 200

# %%
#Write a program that accepts three numbers and prints the largest using comparison and logical operators.

a = 100
b = 80
c = 78


if (a>b and a>c):

 print(f'the largets no. {a}')

elif (b>a and b>c):

 print(f'the largest no.{b}')

else:

 print(f'the largest no.{c}')
# Out:
# the largets no. 100
